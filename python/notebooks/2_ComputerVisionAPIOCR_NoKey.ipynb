# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64
import json
from pprint import pprint

headers = {
    # Request headers
    'Content-Type': 'application/octet-stream', # for image set to octet-stream
    'Ocp-Apim-Subscription-Key': 'key1',
}

params = urllib.parse.urlencode({
    # Request parameters
    #'language': 'en',
    'language': 'de',
    #'language': 'unk', # (AutoDetect)
    'detectOrientation': 'true',
})

# %%
################################
# access image from blob storage
################################
from azure.storage.blob import BlobService

account_name = 'alexanalyticsstorage'
account_key = 'blobkey1'
container_name = 'ocr'
service = BlobService(account_name, account_key)
for blob in service.list_blobs(container_name):
    print(blob.name)
# Out:
# hotel.jpg

# %%
#https://alexanalyticsstorage.blob.core.windows.net/ocr/hotel.jpg
bp =  service.get_blob_properties('ocr','hotel.jpg')
img = service.get_blob_to_bytes('ocr','hotel.jpg')

# %%
try:
    #conn = http.client.HTTPSConnection('api.projectoxford.ai')
    conn = http.client.HTTPSConnection('westus.api.cognitive.microsoft.com')
    conn.request("POST", "/vision/v1.0/ocr?%s" % params, img, headers)
    response = conn.getresponse()
    data = response.read()
    parsed_json = json.loads(data.decode("UTF-8"))
    #print(parsed_json)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
for d in parsed_json["regions"]:
    for l in d["lines"]:
        #print(l)
        for w in l["words"]:
            #print(w)
            print(w["text"])
                #print(t)
        #break
    #break
# Out:
# MICROSOFT
# DEUTSCHLAND
# GMBH
# WALTER-GROPIUS-STRASSE
# 5
# SOS07
# MUENCHEN
# GERMANY
# VAT
# INVOfCE24227S4
# Confirmation
# Number:
# 3302689787
# ALEXANDER
# TODOROVIC
# HILTON
# BERLIN
# 270112017
# 0727m
# Hilton
# BERLIN
# ZVMER
# ZILCUER.FES
# PRES
# DATUM
# 23012017
# 280112017
# 27012017
# SES
# CHREIBUNG
# GUEST
# ROOM
# EXEMPT
# GUEST
# ROOM
# EXEMPT
# AX
# *1003
# BENUTZ
# JAVO
# UEKO
# CUBE
# HHcrjcrs
# S
# REF
# 834122
# 8342133
# SLUE
# 2121273
# -ax-oo
# STR
# ZSFSG
# GESAMTBETRAG
# NETTO
# 19.00%
# GESAVTBETRAG
# NETTO
# 700%
# MWST
# WNST
# CESAUTBETRAG
# INKL
# uwsr
# Guest
# Signature
# co-oo
# â¬243.92
# co-oo
# â¬17.08
# â¬261
# -oo
# Piease
# debit
# my
# account
# by
# the
# amount
# indicated
# above-
# GEBUCHTE
# BEHANDLUNGEN
# 1M
# HEALTH
# CLUB
# WERDEN
# 1M
# NAMEN,
# SIEHE
# EINZELNÃCHVÃJS,
# DURCHGEFÃHRT
# IN
# RECHNUNG
# CESTELLT.
# HILTON
# BERLIN
# MchrenstreÃe
# 30
# 10117
# Tel.
# +49
# (0)30
# 20230-0
# |
# F:
# +49
# (0)30
# 20230-1
# |
# Hilton
# Reservierung
# &
# Kundenservice
# 00
# 800-444
# 58
# 667
# |
# Domhcte!
# GmbH
# I
# Amtsgericht
# Charlottenburg:
# HRB
# 34281
# Stew-NC
# 21210273
# 1
# (ELZIC040000)
# I
# HILTON
# 1
# Fred
# Lowe
# AHHONOR
# EU'OFE
# -
# EAST
# AUSTRALASIA

# %%
pprint(parsed_json)
# Out:
# {'language': 'en',
#  'orientation': 'Up',
#  'regions': [{'boundingBox': '119,1241,1000,692',
#               'lines': [{'boundingBox': '421,1241,698,36',
#                          'words': [{'boundingBox': '421,1241,247,34',
#                                     'text': 'MICROSOFT'},
#                                    {'boundingBox': '677,1243,308,33',
#                                     'text': 'DEUTSCHLAND'},
#                                    {'boundingBox': '997,1245,122,32',
#                                     'text': 'GMBH'}]},
#                         {'boundingBox': '418,1308,615,35',
#                          'words': [{'boundingBox': '418,1308,581,35',
#                                     'text': 'WALTER-GROPIUS-STRASSE'},
#                                    {'boundingBox': '1010,1311,23,32',
#                                     'text': '5'}]},
#                         {'boundingBox': '418,1375,416,33',
#                          'words': [{'boundingBox': '418,1375,114,33',
#                                     'text': 'SOS07'},
#                                    {'boundingBox': '598,1375,236,33',
#                                     'text': 'MUENCHEN'}]},
#                         {'boundingBox': '416,1440,210,33',
#                          'words': [{'boundingBox': '416,1440,210,33',
#                                     'text': 'GERMANY'}]},
#                         {'boundingBox': '122,1701,434,32',
#                          'words': [{'boundingBox': '122,1701,84,31',
#                                     'text': 'VAT'},
#                                    {'boundingBox': '215,1701,341,32',
#                                     'text': 'INVOfCE24227S4'}]},
#                         {'boundingBox': '119,1766,647,32',
#                          'words': [{'boundingBox': '119,1766,234,31',
#                                     'text': 'Confirmation'},
#                                    {'boundingBox': '365,1766,157,31',
#                                     'text': 'Number:'},
#                                    {'boundingBox': '534,1766,232,32',
#                                     'text': '3302689787'}]},
#                         {'boundingBox': '128,1831,513,34',
#                          'words': [{'boundingBox': '128,1832,253,32',
#                                     'text': 'ALEXANDER'},
#                                    {'boundingBox': '387,1831,254,34',
#                                     'text': 'TODOROVIC'}]},
#                         {'boundingBox': '123,1899,700,34',
#                          'words': [{'boundingBox': '123,1899,151,32',
#                                     'text': 'HILTON'},
#                                    {'boundingBox': '285,1899,149,32',
#                                     'text': 'BERLIN'},
#                                    {'boundingBox': '445,1899,205,33',
#                                     'text': '270112017'},
#                                    {'boundingBox': '662,1900,161,33',
#                                     'text': '0727m'}]}]},
#              {'boundingBox': '1312,663,593,943',
#               'lines': [{'boundingBox': '1312,663,373,99',
#                          'words': [{'boundingBox': '1312,663,373,99',
#                                     'text': 'Hilton'}]},
#                         {'boundingBox': '1427,793,140,31',
#                          'words': [{'boundingBox': '1427,793,140,31',
#                                     'text': 'BERLIN'}]},
#                         {'boundingBox': '1617,1247,165,32',
#                          'words': [{'boundingBox': '1617,1247,165,32',
#                                     'text': 'ZVMER'}]},
#                         {'boundingBox': '1614,1510,291,31',
#                          'words': [{'boundingBox': '1614,1510,291,31',
#                                     'text': 'ZILCUER.FES'}]},
#                         {'boundingBox': '1616,1575,125,31',
#                          'words': [{'boundingBox': '1616,1575,125,31',
#                                     'text': 'PRES'}]}]},
#              {'boundingBox': '138,1967,219,281',
#               'lines': [{'boundingBox': '138,1967,146,33',
#                          'words': [{'boundingBox': '138,1967,146,33',
#                                     'text': 'DATUM'}]},
#                         {'boundingBox': '144,2082,206,32',
#                          'words': [{'boundingBox': '144,2082,206,32',
#                                     'text': '23012017'}]},
#                         {'boundingBox': '147,2149,207,32',
#                          'words': [{'boundingBox': '147,2149,207,32',
#                                     'text': '280112017'}]},
#                         {'boundingBox': '150,2216,207,32',
#                          'words': [{'boundingBox': '150,2216,207,32',
#                                     'text': '27012017'}]}]},
#              {'boundingBox': '417,1968,468,280',
#               'lines': [{'boundingBox': '417,1968,339,33',
#                          'words': [{'boundingBox': '417,1968,81,32',
#                                     'text': 'SES'},
#                                    {'boundingBox': '509,1968,247,33',
#                                     'text': 'CHREIBUNG'}]},
#                         {'boundingBox': '422,2082,461,33',
#                          'words': [{'boundingBox': '422,2082,142,32',
#                                     'text': 'GUEST'},
#                                    {'boundingBox': '575,2083,126,32',
#                                     'text': 'ROOM'},
#                                    {'boundingBox': '715,2084,168,31',
#                                     'text': 'EXEMPT'}]},
#                         {'boundingBox': '425,2149,460,33',
#                          'words': [{'boundingBox': '425,2149,143,33',
#                                     'text': 'GUEST'},
#                                    {'boundingBox': '578,2150,127,32',
#                                     'text': 'ROOM'},
#                                    {'boundingBox': '717,2151,168,31',
#                                     'text': 'EXEMPT'}]},
#                         {'boundingBox': '427,2216,175,32',
#                          'words': [{'boundingBox': '427,2217,57,30',
#                                     'text': 'AX'},
#                                    {'boundingBox': '492,2216,110,32',
#                                     'text': '*1003'}]}]},
#              {'boundingBox': '1303,1970,192,280',
#               'lines': [{'boundingBox': '1320,1970,175,32',
#                          'words': [{'boundingBox': '1320,1970,175,32',
#                                     'text': 'BENUTZ'}]},
#                         {'boundingBox': '1303,2085,107,32',
#                          'words': [{'boundingBox': '1303,2085,107,32',
#                                     'text': 'JAVO'}]},
#                         {'boundingBox': '1303,2152,108,32',
#                          'words': [{'boundingBox': '1303,2152,108,32',
#                                     'text': 'UEKO'}]},
#                         {'boundingBox': '1305,2218,118,32',
#                          'words': [{'boundingBox': '1305,2218,118,32',
#                                     'text': 'CUBE'}]}]},
#              {'boundingBox': '1588,1704,228,546',
#               'lines': [{'boundingBox': '1614,1704,202,30',
#                          'words': [{'boundingBox': '1614,1704,166,30',
#                                     'text': 'HHcrjcrs'},
#                                    {'boundingBox': '1790,1704,26,29',
#                                     'text': 'S'}]},
#                         {'boundingBox': '1588,1970,84,32',
#                          'words': [{'boundingBox': '1588,1970,84,32',
#                                     'text': 'REF'}]},
#                         {'boundingBox': '1632,2151,161,33',
#                          'words': [{'boundingBox': '1632,2151,161,33',
#                                     'text': '834122'}]},
#                         {'boundingBox': '1632,2218,161,32',
#                          'words': [{'boundingBox': '1632,2218,161,32',
#                                     'text': '8342133'}]}]},
#              {'boundingBox': '2279,1699,338,549',
#               'lines': [{'boundingBox': '2504,1699,113,31',
#                          'words': [{'boundingBox': '2504,1699,113,31',
#                                     'text': 'SLUE'}]},
#                         {'boundingBox': '2279,1765,194,31',
#                          'words': [{'boundingBox': '2279,1765,194,31',
#                                     'text': '2121273'}]},
#                         {'boundingBox': '2375,2216,169,32',
#                          'words': [{'boundingBox': '2375,2216,169,32',
#                                     'text': '-ax-oo'}]}]},
#              {'boundingBox': '159,2462,495,640',
#               'lines': [{'boundingBox': '159,2462,230,32',
#                          'words': [{'boundingBox': '159,2462,82,32',
#                                     'text': 'STR'},
#                                    {'boundingBox': '251,2462,138,31',
#                                     'text': 'ZSFSG'}]},
#                         {'boundingBox': '160,2528,492,31',
#                          'words': [{'boundingBox': '160,2528,342,31',
#                                     'text': 'GESAMTBETRAG'},
#                                    {'boundingBox': '514,2528,138,31',
#                                     'text': 'NETTO'}]},
#                         {'boundingBox': '165,2574,136,31',
#                          'words': [{'boundingBox': '165,2574,136,31',
#                                     'text': '19.00%'}]},
#                         {'boundingBox': '165,2639,489,32',
#                          'words': [{'boundingBox': '165,2639,341,32',
#                                     'text': 'GESAVTBETRAG'},
#                                    {'boundingBox': '517,2639,137,31',
#                                     'text': 'NETTO'}]},
#                         {'boundingBox': '166,2685,117,31',
#                          'words': [{'boundingBox': '166,2685,117,31',
#                                     'text': '700%'}]},
#                         {'boundingBox': '263,2749,125,31',
#                          'words': [{'boundingBox': '263,2749,125,31',
#                                     'text': 'MWST'}]},
#                         {'boundingBox': '243,2814,125,31',
#                          'words': [{'boundingBox': '243,2814,125,31',
#                                     'text': 'WNST'}]},
#                         {'boundingBox': '176,2877,438,31',
#                          'words': [{'boundingBox': '176,2878,336,30',
#                                     'text': 'CESAUTBETRAG'},
#                                    {'boundingBox': '524,2877,90,30',
#                                     'text': 'INKL'}]},
#                         {'boundingBox': '178,2922,124,31',
#                          'words': [{'boundingBox': '178,2922,124,31',
#                                     'text': 'uwsr'}]},
#                         {'boundingBox': '184,3065,289,37',
#                          'words': [{'boundingBox': '184,3065,108,29',
#                                     'text': 'Guest'},
#                                    {'boundingBox': '301,3065,172,37',
#                                     'text': 'Signature'}]}]},
#              {'boundingBox': '1003,2527,150,379',
#               'lines': [{'boundingBox': '1046,2527,102,32',
#                          'words': [{'boundingBox': '1046,2527,102,32',
#                                     'text': 'co-oo'}]},
#                         {'boundingBox': '1003,2638,147,32',
#                          'words': [{'boundingBox': '1003,2638,147,32',
#                                     'text': 'â¬243.92'}]},
#                         {'boundingBox': '1049,2747,102,32',
#                          'words': [{'boundingBox': '1049,2747,102,32',
#                                     'text': 'co-oo'}]},
#                         {'boundingBox': '1029,2811,123,32',
#                          'words': [{'boundingBox': '1029,2811,123,32',
#                                     'text': 'â¬17.08'}]},
#                         {'boundingBox': '1007,2874,146,32',
#                          'words': [{'boundingBox': '1007,2874,85,32',
#                                     'text': 'â¬261'},
#                                    {'boundingBox': '1098,2875,55,30',
#                                     'text': '-oo'}]}]},
#              {'boundingBox': '188,3125,2818,1736',
#               'lines': [{'boundingBox': '188,3125,996,40',
#                          'words': [{'boundingBox': '188,3128,122,29',
#                                     'text': 'Piease'},
#                                    {'boundingBox': '320,3128,89,29',
#                                     'text': 'debit'},
#                                    {'boundingBox': '418,3136,53,29',
#                                     'text': 'my'},
#                                    {'boundingBox': '482,3131,140,27',
#                                     'text': 'account'},
#                                    {'boundingBox': '632,3128,42,37',
#                                     'text': 'by'},
#                                    {'boundingBox': '683,3128,57,29',
#                                     'text': 'the'},
#                                    {'boundingBox': '751,3130,135,27',
#                                     'text': 'amount'},
#                                    {'boundingBox': '895,3125,159,30',
#                                     'text': 'indicated'},
#                                    {'boundingBox': '1065,3125,119,30',
#                                     'text': 'above-'}]},
#                         {'boundingBox': '193,3221,2551,42',
#                          'words': [{'boundingBox': '193,3227,221,30',
#                                     'text': 'GEBUCHTE'},
#                                    {'boundingBox': '424,3227,330,30',
#                                     'text': 'BEHANDLUNGEN'},
#                                    {'boundingBox': '768,3227,41,29',
#                                     'text': '1M'},
#                                    {'boundingBox': '821,3226,155,30',
#                                     'text': 'HEALTH'},
#                                    {'boundingBox': '989,3226,104,30',
#                                     'text': 'CLUB'},
#                                    {'boundingBox': '1104,3224,175,32',
#                                     'text': 'WERDEN'},
#                                    {'boundingBox': '1292,3224,41,30',
#                                     'text': '1M'},
#                                    {'boundingBox': '1346,3223,151,35',
#                                     'text': 'NAMEN,'},
#                                    {'boundingBox': '1508,3224,119,30',
#                                     'text': 'SIEHE'},
#                                    {'boundingBox': '1638,3224,362,37',
#                                     'text': 'EINZELNÃCHVÃJS,'},
#                                    {'boundingBox': '2013,3221,339,37',
#                                     'text': 'DURCHGEFÃHRT'},
#                                    {'boundingBox': '2460,3229,38,31',
#                                     'text': 'IN'},
#                                    {'boundingBox': '2510,3230,234,33',
#                                     'text': 'RECHNUNG'}]},
#                         {'boundingBox': '196,3270,214,29',
#                          'words': [{'boundingBox': '196,3270,214,29',
#                                     'text': 'CESTELLT.'}]},
#                         {'boundingBox': '1279,4317,364,43',
#                          'words': [{'boundingBox': '1279,4317,178,39',
#                                     'text': 'HILTON'},
#                                    {'boundingBox': '1479,4320,164,40',
#                                     'text': 'BERLIN'}]},
#                         {'boundingBox': '904,4372,599,45',
#                          'words': [{'boundingBox': '904,4372,328,42',
#                                     'text': 'MchrenstreÃe'},
#                                    {'boundingBox': '1255,4378,55,37',
#                                     'text': '30'},
#                                    {'boundingBox': '1382,4381,121,36',
#                                     'text': '10117'}]},
#                         {'boundingBox': '710,4458,994,64',
#                          'words': [{'boundingBox': '710,4458,64,38',
#                                     'text': 'Tel.'},
#                                    {'boundingBox': '786,4461,80,37',
#                                     'text': '+49'},
#                                    {'boundingBox': '878,4462,117,41',
#                                     'text': '(0)30'},
#                                    {'boundingBox': '1006,4464,179,40',
#                                     'text': '20230-0'},
#                                    {'boundingBox': '1208,4466,10,47',
#                                     'text': '|'},
#                                    {'boundingBox': '1242,4467,31,38',
#                                     'text': 'F:'},
#                                    {'boundingBox': '1285,4469,79,37',
#                                     'text': '+49'},
#                                    {'boundingBox': '1377,4469,118,42',
#                                     'text': '(0)30'},
#                                    {'boundingBox': '1507,4472,163,41',
#                                     'text': '20230-1'},
#                                    {'boundingBox': '1695,4475,9,47',
#                                     'text': '|'}]},
#                         {'boundingBox': '273,4510,2384,85',
#                          'words': [{'boundingBox': '273,4510,115,38',
#                                     'text': 'Hilton'},
#                                    {'boundingBox': '401,4512,249,52',
#                                     'text': 'Reservierung'},
#                                    {'boundingBox': '660,4519,31,37',
#                                     'text': '&'},
#                                    {'boundingBox': '704,4519,295,44',
#                                     'text': 'Kundenservice'},
#                                    {'boundingBox': '1012,4526,56,38',
#                                     'text': '00'},
#                                    {'boundingBox': '1081,4527,185,39',
#                                     'text': '800-444'},
#                                    {'boundingBox': '1278,4530,51,38',
#                                     'text': '58'},
#                                    {'boundingBox': '1342,4531,76,39',
#                                     'text': '667'},
#                                    {'boundingBox': '1440,4531,9,48',
#                                     'text': '|'},
#                                    {'boundingBox': '1474,4533,194,43',
#                                     'text': 'Domhcte!'},
#                                    {'boundingBox': '1681,4538,129,41',
#                                     'text': 'GmbH'},
#                                    {'boundingBox': '1834,4541,9,47',
#                                     'text': 'I'},
#                                    {'boundingBox': '1867,4542,243,48',
#                                     'text': 'Amtsgericht'},
#                                    {'boundingBox': '2121,4543,309,52',
#                                     'text': 'Charlottenburg:'},
#                                    {'boundingBox': '2443,4547,84,40',
#                                     'text': 'HRB'},
#                                    {'boundingBox': '2539,4549,118,40',
#                                     'text': '34281'}]},
#                         {'boundingBox': '851,4585,2032,71',
#                          'words': [{'boundingBox': '851,4585,198,40',
#                                     'text': 'Stew-NC'},
#                                    {'boundingBox': '1061,4589,209,42',
#                                     'text': '21210273'},
#                                    {'boundingBox': '1294,4591,10,47',
#                                     'text': '1'},
#                                    {'boundingBox': '1752,4604,364,46',
#                                     'text': '(ELZIC040000)'},
#                                    {'boundingBox': '2141,4605,9,50',
#                                     'text': 'I'},
#                                    {'boundingBox': '2742,4622,141,34',
#                                     'text': 'HILTON'}]},
#                         {'boundingBox': '1555,4661,1451,54',
#                          'words': [{'boundingBox': '1555,4661,10,48',
#                                     'text': '1'},
#                                    {'boundingBox': '2368,4672,82,41',
#                                     'text': 'Fred'},
#                                    {'boundingBox': '2464,4673,102,41',
#                                     'text': 'Lowe'},
#                                    {'boundingBox': '2638,4664,368,51',
#                                     'text': 'AHHONOR'}]},
#                         {'boundingBox': '1144,4818,935,43',
#                          'words': [{'boundingBox': '1144,4818,115,23',
#                                     'text': "EU'OFE"},
#                                    {'boundingBox': '1282,4828,12,9',
#                                     'text': '-'},
#                                    {'boundingBox': '1442,4825,76,23',
#                                     'text': 'EAST'},
#                                    {'boundingBox': '1871,4838,208,23',
#                                     'text': 'AUSTRALASIA'}]}]}],
#  'textAngle': 0.0}

# %%
print(parsed_json["regions"][0]["lines"][0]["words"])
print(parsed_json["regions"][0]["lines"][1]["words"])
print(parsed_json["regions"][0]["lines"][2]["words"])
print(parsed_json["regions"][0]["lines"][3]["words"])
# Out:
# [{'boundingBox': '421,1241,247,34', 'text': 'MICROSOFT'}, {'boundingBox': '677,1243,308,33', 'text': 'DEUTSCHLAND'}, {'boundingBox': '997,1245,122,32', 'text': 'GMBH'}]
# [{'boundingBox': '418,1308,581,35', 'text': 'WALTER-GROPIUS-STRASSE'}, {'boundingBox': '1010,1311,23,32', 'text': '5'}]
# [{'boundingBox': '418,1375,114,33', 'text': 'SOS07'}, {'boundingBox': '598,1375,236,33', 'text': 'MUENCHEN'}]
# [{'boundingBox': '416,1440,210,33', 'text': 'GERMANY'}]
