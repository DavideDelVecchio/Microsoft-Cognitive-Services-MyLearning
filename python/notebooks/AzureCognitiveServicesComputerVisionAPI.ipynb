# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64
import json

headers = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': '6fd30755efb64225bf2048c0c57d1e85',
}

params = urllib.parse.urlencode({
    # Request parameters
    'visualFeatures': 'Description,Categories',
    #'details': '{string}',
    'language': 'en',        
})

# %%
params
# Out:
# 'language=en&visualFeatures=Description%2CCategories'

# %%
# Examples
# http://unsplash.com/photos/anV_zgNDZhc
# http://unsplash.com/photos/kRqA1yFZp1s
try:
    conn = http.client.HTTPSConnection('api.projectoxford.ai')
    conn.request("POST", "/vision/v1.0/analyze?%s" % params, "{'url':'http://unsplash.com/photos/kRqA1yFZp1s/download?force=true'}", headers)
    response = conn.getresponse()
    data = response.read()
    parsed_json = json.loads(data.decode("UTF-8"))
    #print(parsed_json["description"])
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
parsed_json["categories"]
# Out:
# [{'name': 'trans_trainstation', 'score': 0.9765625}]

# %%
parsed_json["description"]["captions"][0]["confidence"]
# Out:
# 0.7001563439485939

# %%
parsed_json["description"]["captions"][0]["text"]
# Out:
# 'a subway train at a train station'
